# %%
import wave
import scipy
import pylab
import librosa
import numpy as np
import pandas as pd
import librosa.display
import matplotlib.pyplot as plt
import soundfile
import os
import glob
from sklearn.model_selection import train_test_split
from datetime import datetime
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import sklearn

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from keras.optimizers import SGD,Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling2D,AveragePooling2D
from keras.layers.convolutional import SeparableConv2D, Conv2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.models import Sequential
from keras import backend as K
from keras import layers
from keras import models
import tensorflow as tf
from keras.metrics import categorical_accuracy
from tensorboard.backend.event_processing import event_accumulator

# %%
train_files = glob.glob("G:\\GTA_audios\\input\\audio_train\\*.wav")  # 训练集
test_files = glob.glob("G:\\GTA_audios\\input\\audio_test\\*.wav")   # 测试集
labels = pd.read_excel("G:\\GTA_audios\\dataset.xlsx") # 训练集的标签

# %%
input_length = 48000*3  ## 表示输入语音的长度，48000表示采样率大小，3表示音频长度大小为3秒，可以根据具体情况进行修改
frame_size = 2048 # 每一帧的长度
hop_size =512 # 帧移大小
def load_audio_file(file_path):
    data, fs = soundfile.read(file=file_path)
    data = data.T
    if len(data)>input_length:  ## 如果音频的长度较长，则通过随机数的形式确定截取区间的范围
        max_offset = len(data)-input_length
        offset = np.random.randint(max_offset)
        data = data[offset:(input_length+offset)]
    elif len(data)<input_length: ## 如果音频的长度不足，通过随机选择padding的界限，将音频尽量集中到中间部分
        if input_length > len(data):
            max_offset = input_length - len(data)
            offset = np.random.randint(max_offset)
        else:
            offset = 0
        data = np.pad(data, (offset, input_length - len(data) - offset), "constant")
    else:
        pass
    #Normalize data
    mean_value = np.mean(data)
    data -= mean_value
    max_value = max(abs(data)) + 0.05 #avoid per zero div
    data = data/max_value
    data = np.reshape(data,[-1,1])
    feature_matrix = get_mel_spectrogram(data, fs)
    return feature_matrix

# %%
def get_mel_spectrogram(audio,sr):
    eps=2.220446049250313e-16
    audio = audio.reshape([1,-1])
    ms = int(0.04*sr) #40ms at 44100 Hz
    window = scipy.signal.hamming(
                                ms,
                                sym=False
                                )
    mel_basis = librosa.filters.mel(sr=sr,
                                    n_fft=2048,
                                    n_mels=128,
                                    htk=False,
                                    norm=None
                                    )
    feature_matrix = np.empty((0,128))
    hop_length = int(sr/50)
    stft = librosa.stft(audio[0,:]+eps,
                            n_fft=2048,
                            win_length=ms,
                            hop_length=hop_length,
                            center=True,
                            window=window
                            )
    # print("stft shape : {}".format(stft.shape))
    spectrogram = np.abs(stft)**2
    mel_spectrogram = np.dot(mel_basis,spectrogram)
    mel_spectrogram = mel_spectrogram.T
    mel_spectrogram = np.log10(mel_spectrogram + eps)
    feature_matrix = np.append(feature_matrix,mel_spectrogram,axis=0)
    return feature_matrix

# %%
# 构建文件标签字典，通过文件名获取对应音频的标签
# 先构造单标签映射的字典
file_to_label = {"G:\\GTA_audios\\input\\audio_train\\"+k:v for k,v in zip(labels["sample"].values, labels["speed"].values)}
list_labels = sorted(list(set(file_to_label.values()))) ## 将所有训练集样本的标签首先构造集合去重，然后排序
label_to_int = {k:v for v,k in enumerate(list_labels)} ## 将每种标签映射到0，1，2……
int_to_label = {v:k for k,v in label_to_int.items()} # 反转
file_to_int = {k:label_to_int[v] for k,v in file_to_label.items()} # 文件名映射到标签值

# %%
train_files = list(file_to_label.keys())
train_labels = [label_to_int[x] for x in file_to_label.values()]

# %%
train_features = [load_audio_file(x) for x in train_files]

# %%
train_features = np.array(train_features)[:,:,:,np.newaxis]
train_labels = np.array(train_labels)
train_labels = train_labels.astype(np.float64)

# %%
train_data,test_data,train_label,test_label =sklearn.model_selection.train_test_split(
    train_features,
    train_labels,
    random_state=42,
    train_size=0.8,
    test_size=0.2
)

# %%
labelencoder = LabelEncoder()
train_label = to_categorical(labelencoder.fit_transform(train_label))
test_label = to_categorical(labelencoder.fit_transform(test_label))
num_labels=train_label.shape[1]

# %%
def gen_model():
    input = layers.Input(shape=(151,128,1))
    # First conv layer
    c_1 = layers.Conv2D(48,(3,8),padding='same')(input)
    c_2 = layers.Conv2D(32,(3,32),padding='same')(input)
    c_3 = layers.Conv2D(16,(3,64),padding='same')(input)
    c_4 = layers.Conv2D(16,(3,90),padding='same')(input)
    conv_1 = layers.Concatenate()([c_1,c_2,c_3,c_4])
    x = layers.BatchNormalization()(conv_1)
    x = layers.ReLU()(x)
#     x = layers.MaxPooling2D((5,5))(x)
    x = layers.AveragePooling2D((5,5))(x)
    # Second conv layer
    x = layers.Conv2D(224,5)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
#     x = layers.MaxPooling2D((11,4))(x)
    x = layers.AveragePooling2D((6,4))(x)
    # Output layer
    x = layers.Flatten()(x)
    # x = layers.Dropout(0.5)(x)
    x = layers.Dense(64)(x)
    x = layers.Dense(5,activation='softmax')(x)
    model = models.Model(input,x)
    return model

# %%
model = gen_model()

# %%
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 151, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 151, 128, 48) 1200        input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 151, 128, 32) 3104        input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 151, 128, 16) 3088        input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 151, 128, 16) 4336        input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 151, 128, 112 0           conv2d_36[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 151, 128, 112 448         concatenate_8[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 151, 128, 112 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 30, 25, 112)  0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 26, 21, 224)  627424      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 26, 21, 224)  896         conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 26, 21, 224)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 4, 5, 224)    0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 4480)         0           average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 64)           286784      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 5)            325         dense_15[0][0]
# ==================================================================================================
# Total params: 927,605
# Trainable params: 926,933
# Non-trainable params: 672
# __________________________________________________________________________________________________

# %%
opt = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=opt,loss ='categorical_crossentropy' , metrics=['accuracy'])
filepath="model_{epoch:02d}-{val_accuracy:.2f}.h5"
checkpoint=ModelCheckpoint(
        filepath=filepath,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        save_weights_only=True,
        period=1
    )
tensorboard = TensorBoard(log_dir='./log_200epoch')
callbacks_list = [tensorboard, checkpoint]
hist = model.fit(train_data, train_label, validation_data=(test_data,test_label),batch_size=32, epochs=200, callbacks=callbacks_list)
# Out:
# Train on 609 samples, validate on 153 samples
# Epoch 1/200
# 609/609 [==============================] - 5s 7ms/step - loss: 3.6100 - accuracy: 0.3990 - val_loss: 4.5788 - val_accuracy: 0.2353
#
# Epoch 00001: val_accuracy improved from -inf to 0.23529, saving model to model_01-0.24.h5
# Epoch 2/200
# 609/609 [==============================] - 4s 7ms/step - loss: 3.8439 - accuracy: 0.3530 - val_loss: 2.5392 - val_accuracy: 0.4183
#
# Epoch 00002: val_accuracy improved from 0.23529 to 0.41830, saving model to model_02-0.42.h5
# Epoch 3/200
# 609/609 [==============================] - 4s 7ms/step - loss: 2.6012 - accuracy: 0.3990 - val_loss: 2.0200 - val_accuracy: 0.2418
#
# Epoch 00003: val_accuracy did not improve from 0.41830
# Epoch 4/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.8900 - accuracy: 0.3990 - val_loss: 4.9989 - val_accuracy: 0.3007
#
# Epoch 00004: val_accuracy did not improve from 0.41830
# Epoch 5/200
# 609/609 [==============================] - 4s 7ms/step - loss: 2.2663 - accuracy: 0.4204 - val_loss: 2.1085 - val_accuracy: 0.4510
#
# Epoch 00005: val_accuracy improved from 0.41830 to 0.45098, saving model to model_05-0.45.h5
# Epoch 6/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.4391 - accuracy: 0.4532 - val_loss: 2.3818 - val_accuracy: 0.2941
#
# Epoch 00006: val_accuracy did not improve from 0.45098
# Epoch 7/200
# 609/609 [==============================] - 4s 7ms/step - loss: 2.2662 - accuracy: 0.4039 - val_loss: 2.4333 - val_accuracy: 0.4510
#
# Epoch 00007: val_accuracy did not improve from 0.45098
# Epoch 8/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.9872 - accuracy: 0.4384 - val_loss: 2.1556 - val_accuracy: 0.5098
#
# Epoch 00008: val_accuracy improved from 0.45098 to 0.50980, saving model to model_08-0.51.h5
# Epoch 9/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.4458 - accuracy: 0.4647 - val_loss: 2.0372 - val_accuracy: 0.4771
#
# Epoch 00009: val_accuracy did not improve from 0.50980
# Epoch 10/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.2582 - accuracy: 0.4384 - val_loss: 1.8929 - val_accuracy: 0.5033
#
# Epoch 00010: val_accuracy did not improve from 0.50980
# Epoch 11/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.5714 - accuracy: 0.4269 - val_loss: 1.6299 - val_accuracy: 0.3137
#
# Epoch 00011: val_accuracy did not improve from 0.50980
# Epoch 12/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.5154 - accuracy: 0.4187 - val_loss: 1.4666 - val_accuracy: 0.4967
#
# Epoch 00012: val_accuracy did not improve from 0.50980
# Epoch 13/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.4209 - accuracy: 0.4713 - val_loss: 2.1415 - val_accuracy: 0.2941
#
# Epoch 00013: val_accuracy did not improve from 0.50980
# Epoch 14/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.7555 - accuracy: 0.4680 - val_loss: 1.4159 - val_accuracy: 0.4379
#
# Epoch 00014: val_accuracy did not improve from 0.50980
# Epoch 15/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.3737 - accuracy: 0.4483 - val_loss: 1.6513 - val_accuracy: 0.4771
#
# Epoch 00015: val_accuracy did not improve from 0.50980
# Epoch 16/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.3726 - accuracy: 0.4450 - val_loss: 1.6280 - val_accuracy: 0.4379
#
# Epoch 00016: val_accuracy did not improve from 0.50980
# Epoch 17/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.2639 - accuracy: 0.4401 - val_loss: 1.4450 - val_accuracy: 0.4967
#
# Epoch 00017: val_accuracy did not improve from 0.50980
# Epoch 18/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.5336 - accuracy: 0.4828 - val_loss: 1.5189 - val_accuracy: 0.3987
#
# Epoch 00018: val_accuracy did not improve from 0.50980
# Epoch 19/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1561 - accuracy: 0.5074 - val_loss: 1.4861 - val_accuracy: 0.4248
#
# Epoch 00019: val_accuracy did not improve from 0.50980
# Epoch 20/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1169 - accuracy: 0.5172 - val_loss: 1.4228 - val_accuracy: 0.4902
#
# Epoch 00020: val_accuracy did not improve from 0.50980
# Epoch 21/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1683 - accuracy: 0.4581 - val_loss: 1.2785 - val_accuracy: 0.5033s: 1.246 - ETA: 0s - loss: 1.1750 - accuracy: 0.
#
# Epoch 00021: val_accuracy did not improve from 0.50980
# Epoch 22/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1171 - accuracy: 0.4860 - val_loss: 1.2600 - val_accuracy: 0.4967
#
# Epoch 00022: val_accuracy did not improve from 0.50980
# Epoch 23/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1286 - accuracy: 0.4877 - val_loss: 1.3589 - val_accuracy: 0.5098
#
# Epoch 00023: val_accuracy did not improve from 0.50980
# Epoch 24/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1821 - accuracy: 0.4778 - val_loss: 1.6017 - val_accuracy: 0.3660
#
# Epoch 00024: val_accuracy did not improve from 0.50980
# Epoch 25/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.4614 - accuracy: 0.3793 - val_loss: 2.6102 - val_accuracy: 0.4248
#
# Epoch 00025: val_accuracy did not improve from 0.50980
# Epoch 26/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.3400 - accuracy: 0.4565 - val_loss: 1.8667 - val_accuracy: 0.5033
#
# Epoch 00026: val_accuracy did not improve from 0.50980
# Epoch 27/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.2286 - accuracy: 0.4401 - val_loss: 1.7433 - val_accuracy: 0.4837
#
# Epoch 00027: val_accuracy did not improve from 0.50980
# Epoch 28/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1509 - accuracy: 0.5008 - val_loss: 1.7166 - val_accuracy: 0.4444
#
# Epoch 00028: val_accuracy did not improve from 0.50980
# Epoch 29/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1364 - accuracy: 0.4959 - val_loss: 1.7028 - val_accuracy: 0.4444
#
# Epoch 00029: val_accuracy did not improve from 0.50980
# Epoch 30/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1775 - accuracy: 0.4877 - val_loss: 1.5821 - val_accuracy: 0.3987
#
# Epoch 00030: val_accuracy did not improve from 0.50980
# Epoch 31/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.2812 - accuracy: 0.4844 - val_loss: 1.7308 - val_accuracy: 0.3987
#
# Epoch 00031: val_accuracy did not improve from 0.50980
# Epoch 32/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.3915 - accuracy: 0.4171 - val_loss: 1.7442 - val_accuracy: 0.4641
#
# Epoch 00032: val_accuracy did not improve from 0.50980
# Epoch 33/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.3825 - accuracy: 0.4696 - val_loss: 1.4710 - val_accuracy: 0.4641
#
# Epoch 00033: val_accuracy did not improve from 0.50980
# Epoch 34/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1272 - accuracy: 0.4877 - val_loss: 1.5393 - val_accuracy: 0.5163
#
# Epoch 00034: val_accuracy improved from 0.50980 to 0.51634, saving model to model_34-0.52.h5
# Epoch 35/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1207 - accuracy: 0.5057 - val_loss: 1.3932 - val_accuracy: 0.4706
#
# Epoch 00035: val_accuracy did not improve from 0.51634
# Epoch 36/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0582 - accuracy: 0.5123 - val_loss: 1.5306 - val_accuracy: 0.4706
#
# Epoch 00036: val_accuracy did not improve from 0.51634
# Epoch 37/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0914 - accuracy: 0.4828 - val_loss: 1.4661 - val_accuracy: 0.4837
#
# Epoch 00037: val_accuracy did not improve from 0.51634
# Epoch 38/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0458 - accuracy: 0.5452 - val_loss: 1.4078 - val_accuracy: 0.4771
#
# Epoch 00038: val_accuracy did not improve from 0.51634
# Epoch 39/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0488 - accuracy: 0.5057 - val_loss: 1.4138 - val_accuracy: 0.5163
#
# Epoch 00039: val_accuracy did not improve from 0.51634
# Epoch 40/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0138 - accuracy: 0.5484 - val_loss: 1.3216 - val_accuracy: 0.4837
# Epoch 00040: val_accuracy did not improve from 0.51634
# Epoch 41/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9976 - accuracy: 0.5402 - val_loss: 1.5314 - val_accuracy: 0.4118
#
# Epoch 00041: val_accuracy did not improve from 0.51634
# Epoch 42/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0499 - accuracy: 0.5107 - val_loss: 1.4072 - val_accuracy: 0.4706
#
# Epoch 00042: val_accuracy did not improve from 0.51634
# Epoch 43/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1404 - accuracy: 0.4943 - val_loss: 1.3296 - val_accuracy: 0.4575
#
# Epoch 00043: val_accuracy did not improve from 0.51634
# Epoch 44/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0436 - accuracy: 0.5090 - val_loss: 1.2880 - val_accuracy: 0.4902
#
# Epoch 00044: val_accuracy did not improve from 0.51634
# Epoch 45/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1501 - accuracy: 0.4992 - val_loss: 1.4910 - val_accuracy: 0.4118
#
# Epoch 00045: val_accuracy did not improve from 0.51634
# Epoch 46/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.2340 - accuracy: 0.4269 - val_loss: 1.5136 - val_accuracy: 0.4641
#
# Epoch 00046: val_accuracy did not improve from 0.51634
# Epoch 47/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0853 - accuracy: 0.4548 - val_loss: 1.4034 - val_accuracy: 0.5098
#
# Epoch 00047: val_accuracy did not improve from 0.51634
# Epoch 48/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0950 - accuracy: 0.5222 - val_loss: 1.2801 - val_accuracy: 0.5098
#
# Epoch 00048: val_accuracy did not improve from 0.51634
# Epoch 49/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1152 - accuracy: 0.4663 - val_loss: 1.2158 - val_accuracy: 0.4967
#
# Epoch 00049: val_accuracy did not improve from 0.51634
# Epoch 50/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9963 - accuracy: 0.5402 - val_loss: 1.2697 - val_accuracy: 0.4967
#
# Epoch 00050: val_accuracy did not improve from 0.51634
# Epoch 51/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9744 - accuracy: 0.5583 - val_loss: 1.1812 - val_accuracy: 0.5294
#
# Epoch 00051: val_accuracy improved from 0.51634 to 0.52941, saving model to model_51-0.53.h5
# Epoch 52/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9687 - accuracy: 0.5517 - val_loss: 1.1843 - val_accuracy: 0.4902
#
# Epoch 00052: val_accuracy did not improve from 0.52941
# Epoch 53/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9407 - accuracy: 0.5583 - val_loss: 1.1627 - val_accuracy: 0.4837
#
# Epoch 00053: val_accuracy did not improve from 0.52941
# Epoch 54/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9269 - accuracy: 0.5534 - val_loss: 1.2365 - val_accuracy: 0.5033
#
# Epoch 00054: val_accuracy did not improve from 0.52941
# Epoch 55/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9308 - accuracy: 0.5484 - val_loss: 1.1935 - val_accuracy: 0.4314
#
# Epoch 00055: val_accuracy did not improve from 0.52941
# Epoch 56/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9469 - accuracy: 0.5468 - val_loss: 1.1795 - val_accuracy: 0.4837
#
# Epoch 00056: val_accuracy did not improve from 0.52941
# Epoch 57/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9093 - accuracy: 0.5550 - val_loss: 1.2262 - val_accuracy: 0.4837
#
# Epoch 00057: val_accuracy did not improve from 0.52941
# Epoch 58/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9843 - accuracy: 0.5287 - val_loss: 1.2773 - val_accuracy: 0.5033
#
# Epoch 00058: val_accuracy did not improve from 0.52941
# Epoch 59/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9979 - accuracy: 0.5222 - val_loss: 1.2729 - val_accuracy: 0.5033
#
# Epoch 00059: val_accuracy did not improve from 0.52941
# Epoch 60/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9220 - accuracy: 0.5698 - val_loss: 1.1431 - val_accuracy: 0.5229
#
# Epoch 00060: val_accuracy did not improve from 0.52941
# Epoch 61/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9267 - accuracy: 0.5698 - val_loss: 1.1837 - val_accuracy: 0.5294
#
# Epoch 00061: val_accuracy did not improve from 0.52941
# Epoch 62/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9082 - accuracy: 0.5731 - val_loss: 1.2289 - val_accuracy: 0.4641
#
# Epoch 00062: val_accuracy did not improve from 0.52941
# Epoch 63/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9256 - accuracy: 0.5649 - val_loss: 1.2588 - val_accuracy: 0.5163
#
# Epoch 00063: val_accuracy did not improve from 0.52941
# Epoch 64/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8929 - accuracy: 0.5764 - val_loss: 1.4579 - val_accuracy: 0.3987
#
# Epoch 00064: val_accuracy did not improve from 0.52941
# Epoch 65/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.7491 - accuracy: 0.4466 - val_loss: 2.4691 - val_accuracy: 0.2941
#
# Epoch 00065: val_accuracy did not improve from 0.52941
# Epoch 66/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0831 - accuracy: 0.5107 - val_loss: 1.3056 - val_accuracy: 0.5098
#
# Epoch 00066: val_accuracy did not improve from 0.52941
# Epoch 67/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0090 - accuracy: 0.5238 - val_loss: 1.3622 - val_accuracy: 0.4641
#
# Epoch 00067: val_accuracy did not improve from 0.52941
# Epoch 68/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1112 - accuracy: 0.5008 - val_loss: 1.5041 - val_accuracy: 0.4314
#
# Epoch 00068: val_accuracy did not improve from 0.52941
# Epoch 69/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.7146 - accuracy: 0.4433 - val_loss: 1.4638 - val_accuracy: 0.5163
#
# Epoch 00069: val_accuracy did not improve from 0.52941
# Epoch 70/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0855 - accuracy: 0.5353 - val_loss: 1.2507 - val_accuracy: 0.4706
#
# Epoch 00070: val_accuracy did not improve from 0.52941
# Epoch 71/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0267 - accuracy: 0.5386 - val_loss: 1.2155 - val_accuracy: 0.4575
#
# Epoch 00071: val_accuracy did not improve from 0.52941
# Epoch 72/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0501 - accuracy: 0.5337 - val_loss: 1.3999 - val_accuracy: 0.5163
#
# Epoch 00072: val_accuracy did not improve from 0.52941
# Epoch 73/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0503 - accuracy: 0.5074 - val_loss: 1.2354 - val_accuracy: 0.5163
#
# Epoch 00073: val_accuracy did not improve from 0.52941
# Epoch 74/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9784 - accuracy: 0.5386 - val_loss: 1.2411 - val_accuracy: 0.5163
#
# Epoch 00074: val_accuracy did not improve from 0.52941
# Epoch 75/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9305 - accuracy: 0.5796 - val_loss: 1.2237 - val_accuracy: 0.4837
#
# Epoch 00075: val_accuracy did not improve from 0.52941
# Epoch 76/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9206 - accuracy: 0.5484 - val_loss: 1.1787 - val_accuracy: 0.5425
#
# Epoch 00076: val_accuracy improved from 0.52941 to 0.54248, saving model to model_76-0.54.h5
# Epoch 77/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0291 - accuracy: 0.5222 - val_loss: 1.2078 - val_accuracy: 0.4641
#
# Epoch 00077: val_accuracy did not improve from 0.54248
# Epoch 78/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9477 - accuracy: 0.5501 - val_loss: 1.1756 - val_accuracy: 0.5098
#
# Epoch 00078: val_accuracy did not improve from 0.54248
# Epoch 79/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9234 - accuracy: 0.5747 - val_loss: 1.1914 - val_accuracy: 0.4967
#
# Epoch 00079: val_accuracy did not improve from 0.54248
# Epoch 80/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9768 - accuracy: 0.5435 - val_loss: 1.2114 - val_accuracy: 0.4444
#
# Epoch 00080: val_accuracy did not improve from 0.54248
# Epoch 81/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9513 - accuracy: 0.5419 - val_loss: 1.2352 - val_accuracy: 0.4706
#
# Epoch 00081: val_accuracy did not improve from 0.54248
# Epoch 82/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9286 - accuracy: 0.5780 - val_loss: 1.1994 - val_accuracy: 0.4706
#
# Epoch 00082: val_accuracy did not improve from 0.54248
# Epoch 83/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9221 - accuracy: 0.5534 - val_loss: 1.2506 - val_accuracy: 0.4771
#
# Epoch 00083: val_accuracy did not improve from 0.54248
# Epoch 84/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8776 - accuracy: 0.6010 - val_loss: 1.1413 - val_accuracy: 0.5163
#
# Epoch 00084: val_accuracy did not improve from 0.54248
# Epoch 85/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0203 - accuracy: 0.5468 - val_loss: 1.4364 - val_accuracy: 0.4771
#
# Epoch 00085: val_accuracy did not improve from 0.54248
# Epoch 86/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0446 - accuracy: 0.5222 - val_loss: 1.3393 - val_accuracy: 0.4641
#
# Epoch 00086: val_accuracy did not improve from 0.54248
# Epoch 87/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9257 - accuracy: 0.5764 - val_loss: 1.2563 - val_accuracy: 0.4967
#
# Epoch 00087: val_accuracy did not improve from 0.54248
# Epoch 88/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9027 - accuracy: 0.5419 - val_loss: 1.2179 - val_accuracy: 0.5098
#
# Epoch 00088: val_accuracy did not improve from 0.54248
# Epoch 89/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8757 - accuracy: 0.5862 - val_loss: 1.1382 - val_accuracy: 0.5163
#
# Epoch 00089: val_accuracy did not improve from 0.54248
# Epoch 90/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8637 - accuracy: 0.6043 - val_loss: 1.2482 - val_accuracy: 0.5294
#
# Epoch 00090: val_accuracy did not improve from 0.54248
# Epoch 91/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8614 - accuracy: 0.6125 - val_loss: 1.1598 - val_accuracy: 0.5229
#
# Epoch 00091: val_accuracy did not improve from 0.54248
# Epoch 92/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8332 - accuracy: 0.6059 - val_loss: 1.1740 - val_accuracy: 0.4641
#
# Epoch 00092: val_accuracy did not improve from 0.54248
# Epoch 93/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0980 - accuracy: 0.4828 - val_loss: 1.4200 - val_accuracy: 0.4967
#
# Epoch 00093: val_accuracy did not improve from 0.54248
# Epoch 94/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9620 - accuracy: 0.5714 - val_loss: 1.2998 - val_accuracy: 0.4967
#
# Epoch 00094: val_accuracy did not improve from 0.54248
# Epoch 95/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9373 - accuracy: 0.5550 - val_loss: 1.1855 - val_accuracy: 0.4837
#
# Epoch 00095: val_accuracy did not improve from 0.54248
# Epoch 96/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8591 - accuracy: 0.6026 - val_loss: 1.1616 - val_accuracy: 0.5033
#
# Epoch 00096: val_accuracy did not improve from 0.54248
# Epoch 97/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8508 - accuracy: 0.5944 - val_loss: 1.1554 - val_accuracy: 0.5294
#
# Epoch 00097: val_accuracy did not improve from 0.54248
# Epoch 98/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8285 - accuracy: 0.6207 - val_loss: 1.2014 - val_accuracy: 0.5359
#
# Epoch 00098: val_accuracy did not improve from 0.54248
# Epoch 99/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8297 - accuracy: 0.5977 - val_loss: 1.1498 - val_accuracy: 0.5229
#
# Epoch 00099: val_accuracy did not improve from 0.54248
# Epoch 100/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7994 - accuracy: 0.6322 - val_loss: 1.2374 - val_accuracy: 0.5163
#
# Epoch 00100: val_accuracy did not improve from 0.54248
# Epoch 101/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8169 - accuracy: 0.6043 - val_loss: 1.1877 - val_accuracy: 0.5294
#
# Epoch 00101: val_accuracy did not improve from 0.54248
# Epoch 102/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7914 - accuracy: 0.6223 - val_loss: 1.1962 - val_accuracy: 0.5163
#
# Epoch 00102: val_accuracy did not improve from 0.54248
# Epoch 103/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7754 - accuracy: 0.6355 - val_loss: 1.3480 - val_accuracy: 0.5490
#
# Epoch 00103: val_accuracy improved from 0.54248 to 0.54902, saving model to model_103-0.55.h5
# Epoch 104/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9469 - accuracy: 0.5813 - val_loss: 1.4574 - val_accuracy: 0.4379
#
# Epoch 00104: val_accuracy did not improve from 0.54902
# Epoch 105/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8951 - accuracy: 0.5731 - val_loss: 1.3033 - val_accuracy: 0.4444
#
# Epoch 00105: val_accuracy did not improve from 0.54902
# Epoch 106/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8063 - accuracy: 0.6256 - val_loss: 1.2687 - val_accuracy: 0.5098
#
# Epoch 00106: val_accuracy did not improve from 0.54902
# Epoch 107/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7932 - accuracy: 0.6453 - val_loss: 1.2079 - val_accuracy: 0.5556
#
# Epoch 00107: val_accuracy improved from 0.54902 to 0.55556, saving model to model_107-0.56.h5
# Epoch 108/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.1497 - accuracy: 0.4926 - val_loss: 1.7896 - val_accuracy: 0.5294
#
# Epoch 00108: val_accuracy did not improve from 0.55556
# Epoch 109/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0624 - accuracy: 0.5714 - val_loss: 1.3409 - val_accuracy: 0.5033
#
# Epoch 00109: val_accuracy did not improve from 0.55556
# Epoch 110/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8842 - accuracy: 0.6043 - val_loss: 1.1872 - val_accuracy: 0.5359
#
# Epoch 00110: val_accuracy did not improve from 0.55556
# Epoch 111/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9354 - accuracy: 0.5616 - val_loss: 1.1355 - val_accuracy: 0.5359
#
# Epoch 00111: val_accuracy did not improve from 0.55556
# Epoch 112/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8237 - accuracy: 0.6404 - val_loss: 1.1965 - val_accuracy: 0.5556
#
# Epoch 00112: val_accuracy did not improve from 0.55556
# Epoch 113/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8057 - accuracy: 0.6026 - val_loss: 1.1910 - val_accuracy: 0.5229
#
# Epoch 00113: val_accuracy did not improve from 0.55556
# Epoch 114/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8650 - accuracy: 0.5829 - val_loss: 1.1722 - val_accuracy: 0.5229
#
# Epoch 00114: val_accuracy did not improve from 0.55556
# Epoch 115/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9579 - accuracy: 0.5550 - val_loss: 1.1319 - val_accuracy: 0.5163
#
# Epoch 00115: val_accuracy did not improve from 0.55556
# Epoch 116/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9241 - accuracy: 0.5731 - val_loss: 1.1299 - val_accuracy: 0.5490
#
# Epoch 00116: val_accuracy did not improve from 0.55556
# Epoch 117/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8308 - accuracy: 0.6125 - val_loss: 1.1585 - val_accuracy: 0.5098
#
# Epoch 00117: val_accuracy did not improve from 0.55556
# Epoch 118/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8001 - accuracy: 0.6174 - val_loss: 1.1484 - val_accuracy: 0.5294cy: 0.61
#
# Epoch 00118: val_accuracy did not improve from 0.55556
# Epoch 119/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7940 - accuracy: 0.6305 - val_loss: 1.1497 - val_accuracy: 0.5294
#
# Epoch 00119: val_accuracy did not improve from 0.55556
# Epoch 120/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7847 - accuracy: 0.6108 - val_loss: 1.1439 - val_accuracy: 0.5621
#
# Epoch 00120: val_accuracy improved from 0.55556 to 0.56209, saving model to model_120-0.56.h5
# Epoch 121/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8152 - accuracy: 0.6158 - val_loss: 1.2283 - val_accuracy: 0.5229
#
# Epoch 00121: val_accuracy did not improve from 0.56209
# Epoch 122/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7875 - accuracy: 0.6404 - val_loss: 1.1694 - val_accuracy: 0.5163
#
# Epoch 00122: val_accuracy did not improve from 0.56209
# Epoch 123/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7783 - accuracy: 0.6190 - val_loss: 1.1074 - val_accuracy: 0.5556
#
# Epoch 00123: val_accuracy did not improve from 0.56209
# Epoch 124/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7590 - accuracy: 0.6568 - val_loss: 1.1797 - val_accuracy: 0.4902
#
# Epoch 00124: val_accuracy did not improve from 0.56209
# Epoch 125/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7851 - accuracy: 0.6158 - val_loss: 1.1186 - val_accuracy: 0.5425
#
# Epoch 00125: val_accuracy did not improve from 0.56209
# Epoch 126/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7556 - accuracy: 0.6355 - val_loss: 1.0352 - val_accuracy: 0.5752
#
# Epoch 00126: val_accuracy improved from 0.56209 to 0.57516, saving model to model_126-0.58.h5
# Epoch 127/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7331 - accuracy: 0.6388 - val_loss: 1.1080 - val_accuracy: 0.5882
#
# Epoch 00127: val_accuracy improved from 0.57516 to 0.58824, saving model to model_127-0.59.h5
# Epoch 128/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7144 - accuracy: 0.6732 - val_loss: 1.1804 - val_accuracy: 0.5163
#
# Epoch 00128: val_accuracy did not improve from 0.58824
# Epoch 129/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7162 - accuracy: 0.6535 - val_loss: 1.1662 - val_accuracy: 0.5229
#
# Epoch 00129: val_accuracy did not improve from 0.58824
# Epoch 130/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7383 - accuracy: 0.6568 - val_loss: 1.1555 - val_accuracy: 0.5556
#
# Epoch 00130: val_accuracy did not improve from 0.58824
# Epoch 131/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6915 - accuracy: 0.6700 - val_loss: 1.1051 - val_accuracy: 0.6013
#
# Epoch 00131: val_accuracy improved from 0.58824 to 0.60131, saving model to model_131-0.60.h5
# Epoch 132/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8633 - accuracy: 0.5862 - val_loss: 1.9858 - val_accuracy: 0.4510
#
# Epoch 00132: val_accuracy did not improve from 0.60131
# Epoch 133/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8342 - accuracy: 0.6273 - val_loss: 1.3038 - val_accuracy: 0.5490
#
# Epoch 00133: val_accuracy did not improve from 0.60131
# Epoch 134/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7529 - accuracy: 0.6650 - val_loss: 1.0750 - val_accuracy: 0.5686
#
# Epoch 00134: val_accuracy did not improve from 0.60131
# Epoch 135/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7397 - accuracy: 0.6650 - val_loss: 1.1463 - val_accuracy: 0.5490
#
# Epoch 00135: val_accuracy did not improve from 0.60131
# Epoch 136/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7008 - accuracy: 0.6814 - val_loss: 1.1684 - val_accuracy: 0.5556
#
# Epoch 00136: val_accuracy did not improve from 0.60131
# Epoch 137/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6906 - accuracy: 0.6946 - val_loss: 1.1587 - val_accuracy: 0.5425
#
# Epoch 00137: val_accuracy did not improve from 0.60131
# Epoch 138/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6718 - accuracy: 0.6765 - val_loss: 1.1738 - val_accuracy: 0.5948
#
# Epoch 00138: val_accuracy did not improve from 0.60131
# Epoch 139/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6578 - accuracy: 0.6962 - val_loss: 1.1159 - val_accuracy: 0.5752
#
# Epoch 00139: val_accuracy did not improve from 0.60131
# Epoch 140/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6672 - accuracy: 0.6929 - val_loss: 1.1815 - val_accuracy: 0.4706
#
# Epoch 00140: val_accuracy did not improve from 0.60131
# Epoch 141/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6501 - accuracy: 0.6765 - val_loss: 1.1155 - val_accuracy: 0.5556
#
# Epoch 00141: val_accuracy did not improve from 0.60131
# Epoch 142/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6712 - accuracy: 0.6732 - val_loss: 1.2315 - val_accuracy: 0.5359
#
# Epoch 00142: val_accuracy did not improve from 0.60131
# Epoch 143/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8476 - accuracy: 0.6289 - val_loss: 1.2335 - val_accuracy: 0.5752
#
# Epoch 00143: val_accuracy did not improve from 0.60131
# Epoch 144/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8104 - accuracy: 0.6158 - val_loss: 1.2475 - val_accuracy: 0.5752
#
# Epoch 00144: val_accuracy did not improve from 0.60131
# Epoch 145/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7163 - accuracy: 0.6453 - val_loss: 1.2052 - val_accuracy: 0.5359
#
# Epoch 00145: val_accuracy did not improve from 0.60131
# Epoch 146/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7004 - accuracy: 0.6634 - val_loss: 1.0760 - val_accuracy: 0.5817
#
# Epoch 00146: val_accuracy did not improve from 0.60131
# Epoch 147/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7244 - accuracy: 0.6371 - val_loss: 1.1520 - val_accuracy: 0.5425
#
# Epoch 00147: val_accuracy did not improve from 0.60131
# Epoch 148/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7046 - accuracy: 0.6552 - val_loss: 1.1334 - val_accuracy: 0.5621
#
# Epoch 00148: val_accuracy did not improve from 0.60131
# Epoch 149/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6695 - accuracy: 0.6847 - val_loss: 1.1142 - val_accuracy: 0.5882
#
# Epoch 00149: val_accuracy did not improve from 0.60131
# Epoch 150/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6739 - accuracy: 0.6979 - val_loss: 1.1572 - val_accuracy: 0.5752
#
# Epoch 00150: val_accuracy did not improve from 0.60131
# Epoch 151/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6579 - accuracy: 0.7028 - val_loss: 1.1649 - val_accuracy: 0.5229
#
# Epoch 00151: val_accuracy did not improve from 0.60131
# Epoch 152/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6207 - accuracy: 0.7110 - val_loss: 1.1684 - val_accuracy: 0.6013
#
# Epoch 00152: val_accuracy did not improve from 0.60131
# Epoch 153/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5958 - accuracy: 0.7225 - val_loss: 1.1277 - val_accuracy: 0.5882
#
# Epoch 00153: val_accuracy did not improve from 0.60131
# Epoch 154/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6025 - accuracy: 0.7291 - val_loss: 1.2206 - val_accuracy: 0.5359
#
# Epoch 00154: val_accuracy did not improve from 0.60131
# Epoch 155/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5832 - accuracy: 0.7521 - val_loss: 1.1854 - val_accuracy: 0.5948
#
# Epoch 00155: val_accuracy did not improve from 0.60131
# Epoch 156/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8311 - accuracy: 0.6470 - val_loss: 1.5906 - val_accuracy: 0.5425
#
# Epoch 00156: val_accuracy did not improve from 0.60131
# Epoch 157/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8967 - accuracy: 0.6207 - val_loss: 1.9040 - val_accuracy: 0.4575
#
# Epoch 00157: val_accuracy did not improve from 0.60131
# Epoch 158/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.0367 - accuracy: 0.5747 - val_loss: 1.5685 - val_accuracy: 0.4118
#
# Epoch 00158: val_accuracy did not improve from 0.60131
# Epoch 159/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8738 - accuracy: 0.5993 - val_loss: 1.1657 - val_accuracy: 0.5686
#
# Epoch 00159: val_accuracy did not improve from 0.60131
# Epoch 160/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7230 - accuracy: 0.6552 - val_loss: 1.1472 - val_accuracy: 0.5294
#
# Epoch 00160: val_accuracy did not improve from 0.60131
# Epoch 161/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6765 - accuracy: 0.7028 - val_loss: 1.1689 - val_accuracy: 0.5359
#
# Epoch 00161: val_accuracy did not improve from 0.60131
# Epoch 162/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6528 - accuracy: 0.7028 - val_loss: 1.1992 - val_accuracy: 0.5490
#
# Epoch 00162: val_accuracy did not improve from 0.60131
# Epoch 163/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6236 - accuracy: 0.7044 - val_loss: 1.2477 - val_accuracy: 0.5425
#
# Epoch 00163: val_accuracy did not improve from 0.60131
# Epoch 164/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6073 - accuracy: 0.7126 - val_loss: 1.2053 - val_accuracy: 0.5752
#
# Epoch 00164: val_accuracy did not improve from 0.60131
# Epoch 165/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6145 - accuracy: 0.7159 - val_loss: 1.3387 - val_accuracy: 0.5359
#
# Epoch 00165: val_accuracy did not improve from 0.60131
# Epoch 166/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6372 - accuracy: 0.7126 - val_loss: 1.2688 - val_accuracy: 0.5686
#
# Epoch 00166: val_accuracy did not improve from 0.60131
# Epoch 167/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6207 - accuracy: 0.7061 - val_loss: 1.3251 - val_accuracy: 0.5098
#
# Epoch 00167: val_accuracy did not improve from 0.60131
# Epoch 168/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5881 - accuracy: 0.7373 - val_loss: 1.2865 - val_accuracy: 0.5425
#
# Epoch 00168: val_accuracy did not improve from 0.60131
# Epoch 169/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5728 - accuracy: 0.7356 - val_loss: 1.2059 - val_accuracy: 0.5686
#
# Epoch 00169: val_accuracy did not improve from 0.60131
# Epoch 170/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5626 - accuracy: 0.7241 - val_loss: 1.2607 - val_accuracy: 0.5490
#
# Epoch 00170: val_accuracy did not improve from 0.60131
# Epoch 171/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5524 - accuracy: 0.7603 - val_loss: 1.2870 - val_accuracy: 0.5490
#
# Epoch 00171: val_accuracy did not improve from 0.60131
# Epoch 172/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5351 - accuracy: 0.7619 - val_loss: 1.3046 - val_accuracy: 0.5490
#
# Epoch 00172: val_accuracy did not improve from 0.60131
# Epoch 173/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5358 - accuracy: 0.7586 - val_loss: 1.3981 - val_accuracy: 0.5098
#
# Epoch 00173: val_accuracy did not improve from 0.60131
# Epoch 174/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6083 - accuracy: 0.7061 - val_loss: 1.7166 - val_accuracy: 0.4837
#
# Epoch 00174: val_accuracy did not improve from 0.60131
# Epoch 175/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6645 - accuracy: 0.6765 - val_loss: 1.4221 - val_accuracy: 0.5294
#
# Epoch 00175: val_accuracy did not improve from 0.60131
# Epoch 176/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5905 - accuracy: 0.7274 - val_loss: 1.3166 - val_accuracy: 0.5294
#
# Epoch 00176: val_accuracy did not improve from 0.60131
# Epoch 177/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5859 - accuracy: 0.7126 - val_loss: 1.4445 - val_accuracy: 0.5098
#
# Epoch 00177: val_accuracy did not improve from 0.60131
# Epoch 178/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.9843 - accuracy: 0.6568 - val_loss: 1.8009 - val_accuracy: 0.5425
#
# Epoch 00178: val_accuracy did not improve from 0.60131
# Epoch 179/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7848 - accuracy: 0.6946 - val_loss: 1.3895 - val_accuracy: 0.5425
#
# Epoch 00179: val_accuracy did not improve from 0.60131
# Epoch 180/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7096 - accuracy: 0.6831 - val_loss: 1.1355 - val_accuracy: 0.5817
#
# Epoch 00180: val_accuracy did not improve from 0.60131
# Epoch 181/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6342 - accuracy: 0.7028 - val_loss: 1.1931 - val_accuracy: 0.6471
#
# Epoch 00181: val_accuracy improved from 0.60131 to 0.64706, saving model to model_181-0.65.h5
# Epoch 182/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.7669 - accuracy: 0.6437 - val_loss: 1.1562 - val_accuracy: 0.5621
#
# Epoch 00182: val_accuracy did not improve from 0.64706
# Epoch 183/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5895 - accuracy: 0.7570 - val_loss: 1.2918 - val_accuracy: 0.5621
#
# Epoch 00183: val_accuracy did not improve from 0.64706
# Epoch 184/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6513 - accuracy: 0.7159 - val_loss: 1.3102 - val_accuracy: 0.6471
#
# Epoch 00184: val_accuracy did not improve from 0.64706
# Epoch 185/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5748 - accuracy: 0.7291 - val_loss: 1.1910 - val_accuracy: 0.6013
#
# Epoch 00185: val_accuracy did not improve from 0.64706
# Epoch 186/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5543 - accuracy: 0.7521 - val_loss: 1.1766 - val_accuracy: 0.6078
#
# Epoch 00186: val_accuracy did not improve from 0.64706
# Epoch 187/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5196 - accuracy: 0.7635 - val_loss: 1.2607 - val_accuracy: 0.6078
#
# Epoch 00187: val_accuracy did not improve from 0.64706
# Epoch 188/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5614 - accuracy: 0.7373 - val_loss: 1.3438 - val_accuracy: 0.4902
#
# Epoch 00188: val_accuracy did not improve from 0.64706
# Epoch 189/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6630 - accuracy: 0.6765 - val_loss: 1.5232 - val_accuracy: 0.5229
#
# Epoch 00189: val_accuracy did not improve from 0.64706
# Epoch 190/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6773 - accuracy: 0.6749 - val_loss: 1.5015 - val_accuracy: 0.4706
#
# Epoch 00190: val_accuracy did not improve from 0.64706
# Epoch 191/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6731 - accuracy: 0.6831 - val_loss: 1.3294 - val_accuracy: 0.5294
#
# Epoch 00191: val_accuracy did not improve from 0.64706
# Epoch 192/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5814 - accuracy: 0.7274 - val_loss: 1.1968 - val_accuracy: 0.5882
#
# Epoch 00192: val_accuracy did not improve from 0.64706
# Epoch 193/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5735 - accuracy: 0.7537 - val_loss: 1.1926 - val_accuracy: 0.6078
#
# Epoch 00193: val_accuracy did not improve from 0.64706
# Epoch 194/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5125 - accuracy: 0.7685 - val_loss: 1.1977 - val_accuracy: 0.5490
#
# Epoch 00194: val_accuracy did not improve from 0.64706
# Epoch 195/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.8009 - accuracy: 0.6486 - val_loss: 1.3614 - val_accuracy: 0.6275
#
# Epoch 00195: val_accuracy did not improve from 0.64706
# Epoch 196/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.6347 - accuracy: 0.7209 - val_loss: 1.3691 - val_accuracy: 0.4967
#
# Epoch 00196: val_accuracy did not improve from 0.64706
# Epoch 197/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5785 - accuracy: 0.7176 - val_loss: 1.3122 - val_accuracy: 0.6209 0.5855 - accuracy
#
# Epoch 00197: val_accuracy did not improve from 0.64706
# Epoch 198/200
# 609/609 [==============================] - 4s 7ms/step - loss: 0.5647 - accuracy: 0.7373 - val_loss: 1.6768 - val_accuracy: 0.4575
#
# Epoch 00198: val_accuracy did not improve from 0.64706
# Epoch 199/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.5788 - accuracy: 0.5057 - val_loss: 3.4561 - val_accuracy: 0.4706
#
# Epoch 00199: val_accuracy did not improve from 0.64706
# Epoch 200/200
# 609/609 [==============================] - 4s 7ms/step - loss: 1.3037 - accuracy: 0.5731 - val_loss: 2.4747 - val_accuracy: 0.5490
#
# Epoch 00200: val_accuracy did not improve from 0.64706

# %%
score = model.evaluate(test_data, test_label, batch_size=16)
# Out:
# 77/77 [==============================] - 0s 2ms/step

# %%
score
# Out:
# [1.1007680738127077, 0.5324675440788269]
